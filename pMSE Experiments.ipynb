# %%
import pandas as pd
import numpy as np
import itertools

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn import preprocessing

from sklearn.tree import DecisionTreeClassifier

from bayes_opt import BayesianOptimization
from bayes_opt import UtilityFunction

import matplotlib.pyplot as plt

from numpy.random import default_rng

from scipy.spatial import KDTree

import time

rng = default_rng()

# %%
# def cart_pmse_ratio(original_data, synthetic_data_sets):
    
#     ### get pmse measures for synthetic data set pairs
    
#     null_pmse_list = []
    
#     inds = np.arange(len(synthetic_data_sets))
    
#     combo_list = list(itertools.combinations(inds, 2))
    
#     for combo in combo_list:
    
#         s1 = synthetic_data_sets[combo[0]]
#         s2 = synthetic_data_sets[combo[1]]
    
#         N_orig = s1.shape[0]
#         N_synth = s2.shape[0]
    
#         c = N_synth/(N_synth+N_orig)
    
#         full_X = pd.concat([s1, s2], axis=0).reset_index(drop=True)
    
#         full_X = preprocessing.StandardScaler().fit_transform(full_X)

#         y = np.repeat([0, 1], repeats=[N_orig, N_synth])
    
#         cart = DecisionTreeClassifier(min_samples_split=20,
#                                       min_samples_leaf=int(np.round(20/3)),
#                                       ccp_alpha=0.0001,
#                                       max_depth=30)
    
#         cart.fit(X=full_X, y=y)
    
#         probs = cart.predict_proba(full_X)
    
#         pMSE = 1/(N_synth + N_orig) * np.sum((probs[:,1] - c)**2)
        
#         null_pmse_list.append(pMSE)
    
#     pmse_list = []
    
#     for s in synthetic_data_sets:
    
#         N_orig = original_data.shape[0]
#         N_synth = s.shape[0]
    
#         c = N_synth/(N_synth+N_orig)
    
#         full_X = pd.concat([original_data, s], axis=0).reset_index(drop=True)
    
#         full_X = preprocessing.StandardScaler().fit_transform(full_X)

#         y = np.repeat([0, 1], repeats=[N_orig, N_synth])
    
#         cart = DecisionTreeClassifier(min_samples_split=20,
#                                       min_samples_leaf=int(np.round(20/3)),
#                                       ccp_alpha=0.0001,
#                                       max_depth=30)
    
#         cart.fit(X=full_X, y=y)
    
#         probs = cart.predict_proba(full_X)
    
#         pMSE = 1/(N_synth + N_orig) * np.sum((probs[:,1] - c)**2)
        
#         pmse_list.append(pMSE)
    
#     return np.array(pmse_list)/np.mean(null_pmse_list)

# %%
def pmse_ratio(original_data, synthetic_data):
    
    N_synth = synthetic_data.shape[0]
    N_orig = original_data.shape[0]
    
    # combine original and synthetic datasets
    full_X = pd.concat([original_data, synthetic_data], axis=0).reset_index(drop=True)
    
    # generate interactions and powers of variables
    poly = PolynomialFeatures(3, interaction_only=False, include_bias=False)
    
    full_X = poly.fit_transform(full_X)

    # scale the combined dataset
    full_X = preprocessing.StandardScaler().fit_transform(full_X)
    
    c = N_synth/(N_synth+N_orig)

    y = np.repeat([0, 1], repeats=[N_orig, N_synth])
    
    pMSE_model = LogisticRegression(penalty=None, max_iter=1000).fit(full_X, y)
    
    probs = pMSE_model.predict_proba(full_X)
    
    pMSE = 1/(N_synth+N_orig) * np.sum((probs[:,1] - c)**2)
    
    e_pMSE = 2*(full_X.shape[1])*(1-c)**2 * c/(N_synth+N_orig)
        
    return pMSE/e_pMSE

# %%
def privacy_metrics(train_data, holdout_data, synthetic_data, delta):
    
    training_tree = KDTree(train_data)
    
    holdout_dists, holdout_neighbors = training_tree.query(x=holdout_data, k=5, p=2)
    
    synthetic_dists, synthetic_neighbors = training_tree.query(x=synthetic_data, k=5, p=2)
    
    IMS_holdout = np.mean(holdout_dists[:,0] <= delta)
    
    IMS_synthetic = np.mean(synthetic_dists[:,0] <= delta)
    
    DCR_holdout = np.percentile(holdout_dists[:,0], q=5)
    
    DCR_synthetic = np.percentile(synthetic_dists[:,0], q=5)
    
    ratios_synthetic = synthetic_dists[:,0]/synthetic_dists[:,-1]
    
    ratios_holdout = holdout_dists[:,0]/holdout_dists[:,-1]
    
    NNDR_synthetic = np.percentile(ratios_synthetic, q=5)
    
    NNDR_holdout = np.percentile(ratios_holdout, q=5)
    
    return ({"IMS_holdout": IMS_holdout, "IMS_synthetic": IMS_synthetic,
             "DCR_holdout": DCR_holdout, "DCR_synthetic": DCR_synthetic,
             "NNDR_holdout": NNDR_holdout, "NNDR_synthetic": NNDR_synthetic})

# %% [markdown]
# ***

# %%
ss=500

# %%
m = np.zeros((10))
diag = np.repeat(1.0, 10)
        
covmat = np.zeros((10, 10))
np.fill_diagonal(covmat, diag)

pmse_list = []

nreps = 10

for r in range(nreps):
    training = pd.DataFrame(rng.multivariate_normal(mean=m, cov=covmat, size=ss))
    # synthetic = pd.DataFrame(rng.multivariate_normal(mean=np.mean(training, axis=0), cov=np.cov(training, rowvar=False), size=ss))
    synthetic = pd.DataFrame(rng.multivariate_normal(mean=m, cov=covmat, size=ss))
    
    pmse_list.append(pmse_ratio(training, synthetic))

# %%
np.mean(pmse_list)
# Out:
# 1.1006835422843602

# %% [markdown]
# ***

# %% [markdown]
# # Simulation 1: Privacy Metrics When Data Come From The Same Sampling Distribution

# %% [markdown]
# Structure simulation the same way as Snoke et al. 2018.
#
# * 1000 simulations
# * For each simulation
#     * generate 10 data sets, each of size $N = 5000$
#         * each data is multivariate normal with $\mu = 0$ and $\sigma^2 = 1$ with covariances equal to 0, 0.1, ..., 0.9 for each data set.

# %%
def privacy_simulation(sample_size, covariance_values, nreps):
    
    m = np.zeros((10))
    diag = np.repeat(1.0, 10)
    
    results_dict = {}
    
    for v in covariance_values:
        
        covmat = np.zeros((10, 10))
        covmat[:,:] = v
        np.fill_diagonal(covmat, diag)
        
        results_dict[str(v)] = []
        
        for r in range(nreps):
        
            training = pd.DataFrame(rng.multivariate_normal(mean=m, cov=covmat, size=sample_size))
            holdout = pd.DataFrame(rng.multivariate_normal(mean=m, cov=covmat, size=sample_size))
            synthetic = pd.DataFrame(rng.multivariate_normal(mean=m, cov=covmat, size=sample_size))
            
            metrics = privacy_metrics(training, holdout, synthetic, delta=1)
            
            metrics['pmse_th'] = pmse_ratio(training, holdout)
            metrics['pmse_ts'] = pmse_ratio(training, synthetic)
            
            results_dict[str(v)].append(metrics)
            
    return results_dict

# %%
reps = 1000
sample_size = 5000
cov_vals = np.linspace(start=0.0, stop=0.9, num=10)

# %%
tic = time.perf_counter()
privacy_results = privacy_simulation(sample_size=sample_size, covariance_values=cov_vals, nreps=reps)
toc = time.perf_counter()
print(f"Completed in {(toc - tic)/60:0.4f} minutes")
# Out:
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Completed in 185.1914 minutes
# C:\Users\camer\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(f"Completed in {(toc - tic)/60:0.4f} minutes")
# Out:
# Completed in 185.1914 minutes

# %%
print("Difference in Mean Synthetic IMS and Mean Holdout IMS for Each Covariance Value")

np.round(np.array([np.mean([x['IMS_synthetic'] for x in privacy_results[str(i)]]) for i in cov_vals]) - np.array([np.mean([x['IMS_holdout'] for x in privacy_results[str(i)]]) for i in cov_vals]), 4)
# Out:
# Difference in Mean Synthetic IMS and Mean Holdout IMS for Each Covariance Value
# array([ 0.    , -0.0001, -0.    ,  0.    , -0.0004,  0.0001, -0.0003,
#         0.0002,  0.0001,  0.    ])

# %%
print("Difference in Mean Synthetic DCR and Mean Holdout DCR for Each Covariance Value")

np.round(np.array([np.mean([x['DCR_synthetic'] for x in privacy_results[str(i)]]) for i in cov_vals]) - np.array([np.mean([x['DCR_holdout'] for x in privacy_results[str(i)]]) for i in cov_vals]), 4)
# Out:
# Difference in Mean Synthetic DCR and Mean Holdout DCR for Each Covariance Value
# array([ 0.0003,  0.0005,  0.0001,  0.0001,  0.0004,  0.    , -0.    ,
#        -0.0004, -0.    , -0.    ])

# %%
print("Difference in Mean Synthetic NNDR and Mean Holdout NNDR for Each Covariance Value")

np.round(np.array([np.mean([x['NNDR_synthetic'] for x in privacy_results[str(i)]]) for i in cov_vals]) - np.array([np.mean([x['NNDR_holdout'] for x in privacy_results[str(i)]]) for i in cov_vals]), 4)
# Out:
# Difference in Mean Synthetic NNDR and Mean Holdout NNDR for Each Covariance Value
# array([ 0.0002,  0.0001,  0.0002, -0.0002,  0.0002,  0.0002, -0.0004,
#        -0.0005,  0.0002, -0.0001])

# %%
print("Mean pMSE Ratio for Training vs. Synthetic")
[np.mean([x['pmse_ts'] for x in privacy_results[str(i)]]) for i in cov_vals]
# Out:
# Mean pMSE Ratio for Training vs. Synthetic
# [1.0057254418707788,
#  1.0067915464803854,
#  1.006118320733229,
#  1.0064708827907618,
#  1.009527445077215,
#  1.0071752712716602,
#  1.0060440162571067,
#  1.0129673045960084,
#  1.011016564620905,
#  0.9945871497632763]

# %% [markdown]
# ***

# %% [markdown]
# ### Simulation 2: Test Whether Bayesian Optimization Can Recover the Correct Parameter

# %% [markdown]
# Steps:
#
# * sample data from normal distribution - call it train
# * use bayesian optimization to choose mean and variane parameters
# * check whether bayesian optimization found the correct parameters, and what the resulting pmse ratio is

# %% [markdown]
# The first simulation has mean $(0, 0)$ and diagonal covariance matrix with variances of $(1, 1)$.

# %%
def synthesis_model(train_data, number_synthetic_datasets, m1_, m2_, v1_, v2_):
    
    # number of samples to draw
    num_samples = train_data.shape[0]
    
    mean_vec = np.array([m1_, m2_])
    covariance_mat = np.zeros((2, 2))
    covmat_diag = np.array([v1_, v2_])
    np.fill_diagonal(covariance_mat, covmat_diag)
    
    sXs = [pd.DataFrame(rng.multivariate_normal(mean=mean_vec, cov=covariance_mat, size=num_samples)) for i in range(number_synthetic_datasets)]
        
    ###### Calculate pMSE ratios ######
    pmse_ratios = [pmse_ratio(train_data, Y) for Y in sXs]
    
    return pmse_ratios

# %%
def optimize_synthesis(train_data, number_synthetic_datasets):

    def evaluate_model(m1_, m2_, v1_, v2_):

        pmse_ratios = synthesis_model(train_data=train_data,
                                      number_synthetic_datasets=number_synthetic_datasets,
                                      m1_=m1_,
                                      m2_=m2_,
                                      v1_=v1_,
                                      v2_=v2_)

        return -1 * ((1 - np.mean(pmse_ratios))**2)

    optimizer = BayesianOptimization(
        f=evaluate_model,
        pbounds={
            "m1_": (-5, 5),
            "m2_": (-5, 5),
            "v1_": (0.1, 3),
            "v2_": (0.1, 3)
        })
    
    utility = UtilityFunction(kind="ei", xi=1e-10)
    # optimizer.set_gp_params(alpha=1e-3)
    optimizer.maximize(init_points=5, n_iter=400, acquisition_function=utility)
    print("Final Result: ", optimizer.max)
    return optimizer.max, optimizer

# %%
M = 20

m = np.zeros((2))
covmat = np.zeros((2, 2))
diag = np.repeat(1.0, 2)
np.fill_diagonal(covmat, diag)

# %%
sample = pd.DataFrame(rng.multivariate_normal(mean=m, cov=covmat, size=sample_size))

# %%
optimization_results = [optimize_synthesis(train_data=sample, number_synthetic_datasets=M) for r in range(5)]
# Out:
# |   iter    |  target   |    m1_    |    m2_    |    v1_    |    v2_    |
# -------------------------------------------------------------------------
# | 1         | -1.028e+0 | -1.251    | -4.694    | 2.793     | 2.602     |
# | 2         | -1.08e+06 | 3.506     | -4.017    | 2.515     | 2.922     |
# | 3         | -9.599e+0 | -3.564    | 1.483     | 1.439     | 1.523     |
# | 4         | -1.105e+0 | 4.373     | -2.238    | 1.802     | 1.498     |
# | 5         | -9.268e+0 | 3.659     | 0.4952    | 1.362     | 0.4796    |
# | 6         | -9.783e+0 | 3.511     | 1.067     | 1.269     | 0.2651    |
# | 7         | -8.632e+0 | 3.641     | 0.2015    | 1.569     | 0.8078    |
# | 8         | -7.966e+0 | 3.545     | 0.09459   | 1.797     | 1.138     |
# | 9         | -6.987e+0 | 3.381     | 0.1184    | 2.068     | 1.506     |
# | 10        | -6.047e+0 | 3.164     | 0.2539    | 2.374     | 1.905     |
# | 11        | -5.068e+0 | 2.915     | 0.5317    | 2.773     | 2.405     |
# | 12        | -5.021e+0 | 2.763     | 1.013     | 3.0       | 3.0       |
# | 13        | -2.722e+0 | 2.083     | 0.4856    | 3.0       | 2.678     |
# | 14        | -1.192e+0 | 1.285     | 0.2927    | 3.0       | 2.691     |
# | 15        | -6.977e+0 | 0.6344    | 0.1808    | 3.0       | 3.0       |
# | 16        | -8.127e+0 | 0.2648    | 0.8551    | 3.0       | 2.787     |
# | 17        | -3.923e+0 | 0.2607    | 0.1535    | 3.0       | 2.326     |
# | 18        | -2.585e+0 | 0.2278    | 0.1392    | 2.129     | 2.578     |
# | 19        | -1.868e+0 | 0.09799   | -0.09452  | 0.1       | 3.0       |
# | 20        | -3.402e+0 | -0.2245   | -0.07482  | 2.081     | 3.0       |
# | 21        | -2.854e+0 | 0.1415    | -0.3186   | 2.198     | 2.573     |
# | 22        | -2.019e+0 | 0.1039    | -0.3542   | 3.0       | 0.1       |
# | 23        | -2.672e+0 | -0.2098   | -0.1664   | 2.441     | 2.273     |
# | 24        | -2.981e+0 | 0.0683    | -0.1161   | 2.521     | 2.463     |
# | 25        | -6.469e+0 | -0.1204   | -0.4185   | 1.417     | 1.638     |
# | 26        | -1.433e+0 | -0.3274   | 0.04869   | 1.61      | 2.239     |
# | 27        | -8.773e+0 | -0.8693   | -1.515    | 0.1       | 0.1       |
# | 28        | -2.091e+0 | 0.1126    | -0.07046  | 1.321     | 1.687     |
# | 29        | -6.949e+0 | 0.1912    | -0.1611   | 1.589     | 1.911     |
# | 30        | -5.831e+0 | -0.2808   | 0.1591    | 2.087     | 1.108     |
# | 31        | -2.97e+03 | 0.161     | 0.1168    | 1.601     | 1.534     |
# | 32        | -6.875e+0 | -0.3712   | 0.1106    | 1.628     | 1.575     |
# | 33        | -1.232e+0 | -0.6139   | 5.0       | 3.0       | 0.1       |
# | 34        | -3.506e+0 | -0.09417  | -0.0629   | 1.778     | 1.478     |
# | 35        | -3.093e+0 | -0.03019  | 0.6857    | 2.317     | 1.5       |
# | 36        | -2.5e+03  | -0.1593   | 0.3275    | 1.463     | 1.018     |
# | 37        | -1.362e+0 | 0.03598   | -0.4002   | 1.384     | 2.435     |
# | 38        | -4.069e+0 | 0.09474   | 0.3744    | 1.565     | 1.355     |
# | 39        | -1.052e+0 | -0.2033   | 0.4608    | 1.725     | 0.7826    |
# | 40        | -4.256e+0 | -0.1217   | -0.1191   | 1.371     | 1.868     |
# | 41        | -1.232e+0 | -5.0      | -5.0      | 0.1       | 3.0       |
# | 42        | -1.505e+0 | -0.07786  | 0.1776    | 1.602     | 1.194     |
# | 43        | -1.174e+0 | -0.01748  | 0.1106    | 1.423     | 1.438     |
# | 44        | -1.113e+0 | 0.1998    | 0.2686    | 1.274     | 1.122     |
# | 45        | -1.232e+0 | 5.0       | 5.0       | 0.1       | 3.0       |
# | 46        | -5.532e+0 | -0.9636   | 0.1913    | 2.869     | 1.708     |
# | 47        | -931.9    | 0.0912    | 0.2392    | 1.379     | 1.199     |
# | 48        | -7.742e+0 | 0.2699    | 0.9484    | 0.4873    | 0.9149    |
# | 49        | -1.802e+0 | -1.427    | -0.7752   | 3.0       | 3.0       |
# | 50        | -1.252e+0 | 0.4439    | 0.424     | 1.089     | 1.732     |
# | 51        | -1.726e+0 | -0.34     | -0.4193   | 1.637     | 2.053     |
# | 52        | -1.291e+0 | 0.1895    | 0.2757    | 1.161     | 1.312     |
# | 53        | -5.078e+0 | -0.08382  | 1.03      | 1.318     | 3.0       |
# | 54        | -1.162e+0 | -0.2144   | 0.5266    | 1.05      | 1.996     |
# | 55        | -7.964e+0 | 0.04292   | 0.4128    | 1.339     | 1.971     |
# | 56        | -3.443e+0 | 0.07205   | 0.4503    | 1.243     | 1.167     |
# | 57        | -7.365e+0 | 0.4948    | -0.2409   | 1.66      | 1.234     |
# | 58        | -1.152e+0 | 0.262     | -0.01923  | 1.384     | 1.32      |
# | 59        | -2.3e+03  | 0.2911    | 0.1017    | 1.741     | 0.9899    |
# | 60        | -1.076e+0 | 0.1877    | 0.09587   | 1.572     | 1.138     |
# | 61        | -1.372e+0 | 0.07156   | 0.2358    | 1.584     | 0.9862    |
# | 62        | -1.382e+0 | 0.1815    | -0.2226   | 2.456     | 1.541     |
# | 63        | -3.156e+0 | 0.2073    | -0.1559   | 1.713     | 1.367     |
# | 64        | -1.232e+0 | -5.0      | 5.0       | 0.1       | 3.0       |
# | 65        | -3.544e+0 | 0.1225    | 0.1405    | 1.967     | 1.169     |
# | 66        | -1.045e+0 | 0.2157    | 0.1562    | 1.325     | 1.308     |
# | 67        | -525.0    | 0.06057   | 0.1273    | 1.206     | 1.4       |
# | 68        | -1.3e+03  | 0.01586   | 0.2169    | 1.142     | 1.549     |
# | 69        | -290.8    | 0.1132    | 0.1247    | 1.284     | 1.197     |
# | 70        | -332.8    | 0.1861    | 0.07058   | 1.198     | 1.242     |
# | 71        | -503.6    | 0.2437    | 0.07044   | 1.383     | 0.9923    |
# | 72        | -1.411e+0 | -1.072    | 0.855     | 3.0       | 3.0       |
# | 73        | -6.702e+0 | 0.265     | -0.3982   | 1.159     | 1.757     |
# | 74        | -2.437e+0 | 0.321     | 0.2085    | 1.382     | 3.0       |
# | 75        | -459.8    | 0.03415   | 0.1601    | 1.078     | 1.384     |
# | 76        | -5.139e+0 | -0.2059   | -0.7069   | 3.0       | 1.806     |
# | 77        | -503.4    | 0.09331   | 0.01812   | 0.9557    | 1.463     |
# | 78        | -3.487e+0 | 0.0785    | 0.3639    | 0.8299    | 1.571     |
# | 79        | -755.7    | 0.1686    | 0.08357   | 1.015     | 1.466     |
# | 80        | -542.3    | 0.05963   | -0.04092  | 1.119     | 1.489     |
# | 81        | -2.732e+0 | 0.003013  | 0.008322  | 0.9007    | 1.878     |
# | 82        | -7.652e+0 | 0.07064   | 0.1648    | 1.138     | 2.333     |
# | 83        | -1.521e+0 | 0.3823    | -0.05047  | 1.061     | 1.202     |
# | 84        | -689.3    | 0.2911    | 0.08098   | 1.243     | 1.113     |
# | 85        | -233.0    | 0.1699    | 0.1143    | 1.073     | 1.228     |
# | 86        | -672.0    | -0.03336  | -0.1611   | 1.459     | 1.146     |
# | 87        | -1.088e+0 | -0.01298  | 0.08975   | 0.9936    | 1.612     |
# | 88        | -3.45e+03 | -0.3311   | -0.1213   | 1.73      | 0.8984    |
# | 89        | -2.647e+0 | -0.05863  | -0.1609   | 1.874     | 0.9921    |
# | 90        | -3.967e+0 | -0.08114  | 0.2295    | 1.411     | 0.5741    |
# | 91        | -600.4    | -0.06556  | 0.06444   | 1.537     | 0.8732    |
# | 92        | -1.448e+0 | -0.1964   | -0.04938  | 1.644     | 1.118     |
# | 93        | -375.8    | 0.1908    | -0.1383   | 1.32      | 1.035     |
# | 94        | -136.5    | 0.0771    | 0.1208    | 1.28      | 0.9272    |
# | 95        | -162.6    | -0.0411   | -0.05286  | 1.214     | 1.255     |
# | 96        | -124.2    | 0.1153    | -0.05164  | 1.235     | 1.182     |
# | 97        | -654.8    | 0.1358    | 0.08542   | 1.436     | 0.7932    |
# | 98        | -1.257e+0 | -0.4386   | -0.2459   | 2.176     | 1.276     |
# | 99        | -63.03    | 0.06825   | 0.04067   | 1.264     | 1.093     |
# | 100       | -49.72    | 0.007606  | 0.09148   | 1.139     | 1.151     |
# | 101       | -119.8    | 0.1258    | -0.02023  | 1.155     | 1.213     |
# | 102       | -176.8    | 0.08898   | 0.09621   | 1.35      | 1.07      |
# | 103       | -270.6    | 0.05196   | 0.1631    | 1.336     | 0.9969    |
# | 104       | -2.262e+0 | -0.1571   | 0.3338    | 0.813     | 1.213     |
# | 105       | -314.8    | -0.03661  | 0.2309    | 1.03      | 1.158     |
# | 106       | -2.045e+0 | -0.3498   | -0.03483  | 1.157     | 1.322     |
# | 107       | -6.736e+0 | -0.4556   | 0.3038    | 1.076     | 1.191     |
# | 108       | -564.9    | -0.111    | 0.1647    | 0.9794    | 1.329     |
# | 109       | -51.88    | 0.11      | 0.1338    | 1.077     | 1.028     |
# | 110       | -44.21    | 0.1237    | 0.06832   | 1.175     | 1.054     |
# | 111       | -2.708e+0 | -0.3784   | 0.2241    | 1.288     | 3.0       |
# | 112       | -214.9    | 0.08156   | 0.1663    | 0.9222    | 1.206     |
# | 113       | -419.9    | -0.1603   | 0.03569   | 1.282     | 1.226     |
# | 114       | -139.1    | -0.03746  | 0.1795    | 1.156     | 0.9533    |
# | 115       | -608.3    | -0.1002   | -0.07837  | 1.271     | 1.374     |
# | 116       | -55.4     | 0.08578   | 0.005744  | 1.103     | 1.21      |
# | 117       | -300.7    | -0.00921  | 0.03223   | 1.096     | 1.404     |
# | 118       | -967.8    | 0.157     | 0.1364    | 0.8517    | 0.6854    |
# | 119       | -8.098e+0 | 0.5133    | -0.1721   | 1.277     | 0.641     |
# | 120       | -435.6    | -0.05532  | 0.1256    | 1.151     | 0.7092    |
# | 121       | -341.4    | 0.1677    | 0.1282    | 1.036     | 0.7617    |
# | 122       | -295.9    | -0.07305  | 0.1895    | 1.193     | 0.86      |
# | 123       | -6.591e+0 | -0.121    | 0.6063    | 0.9504    | 0.2699    |
# | 124       | -1.07e+03 | 0.2301    | 0.1735    | 0.763     | 0.954     |
# | 125       | -350.0    | -0.186    | 0.00598   | 1.159     | 0.7726    |
# | 126       | -711.5    | -0.186    | 0.159     | 0.8308    | 0.8907    |
# | 127       | -34.43    | 0.02987   | 0.07417   | 0.8844    | 0.8881    |
# | 128       | -998.0    | -0.2963   | 0.1418    | 1.127     | 1.056     |
# | 129       | -865.8    | 0.08809   | -0.2454   | 1.119     | 1.372     |
# | 130       | -74.85    | -0.06327  | 0.134     | 0.9358    | 0.9223    |
# | 131       | -624.9    | 0.1238    | -0.04738  | 0.6884    | 0.9323    |
# | 132       | -404.5    | 0.2296    | -0.000386 | 0.878     | 0.8235    |
# | 133       | -401.1    | -0.2045   | -0.04285  | 1.02      | 1.238     |
# | 134       | -124.6    | -0.0824   | 0.006005  | 0.8362    | 1.122     |
# | 135       | -115.7    | -0.1005   | 0.0492    | 1.22      | 0.8486    |
# | 136       | -1.258e+0 | 0.03888   | -0.02936  | 0.4235    | 1.548     |
# | 137       | -1.199e+0 | -0.00884  | 0.2483    | 0.7157    | 0.8934    |
# | 138       | -1.409e+0 | -0.2984   | -0.07594  | 1.463     | 0.9299    |
# | 139       | -409.0    | -0.1813   | -0.02506  | 1.369     | 1.069     |
# | 140       | -422.5    | 0.03635   | 0.09785   | 0.7115    | 1.012     |
# | 141       | -727.1    | 0.1802    | -0.1487   | 1.141     | 1.365     |
# | 142       | -237.1    | -0.1317   | -0.02832  | 1.173     | 1.247     |
# | 143       | -1.045e+0 | 0.3311    | -0.07522  | 0.9769    | 0.8109    |
# | 144       | -204.1    | 0.04256   | -0.2079   | 1.126     | 1.113     |
# | 145       | -396.6    | 0.2066    | -0.1686   | 1.155     | 1.131     |
# | 146       | -1.808e+0 | 0.6597    | 0.06711   | 0.7715    | 0.6942    |
# | 147       | -51.47    | 0.04183   | 0.05741   | 0.97      | 0.7937    |
# | 148       | -456.6    | -0.03711  | -0.02241  | 1.264     | 0.7043    |
# | 149       | -2.001e+0 | -0.2779   | 0.09488   | 0.7401    | 1.155     |
# | 150       | -2.677e+0 | 0.3625    | -0.2704   | 0.9817    | 0.965     |
# | 151       | -44.9     | -0.1335   | 0.04057   | 1.038     | 0.9928    |
# | 152       | -523.4    | 0.1144    | -0.04354  | 0.7213    | 1.139     |
# | 153       | -738.6    | -0.2315   | 0.1152    | 0.89      | 1.179     |
# | 154       | -226.0    | -0.07055  | -0.1483   | 0.9458    | 1.224     |
# | 155       | -321.0    | 0.001493  | 0.1546    | 0.9132    | 1.297     |
# | 156       | -560.6    | 0.1812    | -0.2014   | 1.192     | 1.165     |
# | 157       | -512.3    | -0.06556  | 0.04896   | 1.461     | 1.203     |
# | 158       | -51.79    | 0.0515    | -0.0785   | 0.9685    | 1.193     |
# | 159       | -281.9    | -0.121    | 0.1977    | 1.076     | 1.088     |
# | 160       | -305.6    | 0.01021   | -0.06466  | 1.446     | 1.085     |
# | 161       | -212.8    | -0.09582  | -0.1022   | 1.065     | 1.268     |
# | 162       | -859.5    | 0.3273    | 0.02335   | 1.291     | 0.8815    |
# | 163       | -1.65e+03 | 0.2007    | -0.03515  | 1.558     | 0.7163    |
# | 164       | -158.8    | 0.08224   | 0.08596   | 0.8192    | 0.8552    |
# | 165       | -145.9    | 0.1144    | 0.05792   | 1.229     | 0.8032    |
# | 166       | -102.5    | 0.1636    | 0.08272   | 1.005     | 1.134     |
# | 167       | -65.87    | 0.1409    | -0.08306  | 0.9398    | 1.083     |
# | 168       | -15.64    | -0.03252  | -0.07082  | 1.101     | 1.11      |
# | 169       | -204.4    | -0.09155  | 0.1408    | 1.194     | 0.8369    |
# | 170       | -2.502e+0 | 0.2567    | -0.148    | 0.8124    | 1.501     |
# | 171       | -46.23    | -0.05958  | 0.06501   | 1.17      | 1.121     |
# | 172       | -256.5    | 0.09427   | 0.06845   | 1.273     | 0.7665    |
# | 173       | -7.631e+0 | -0.3304   | -0.09069  | 0.7327    | 1.742     |
# | 174       | -1.446e+0 | -0.1106   | -0.078    | 0.8512    | 1.573     |
# | 175       | -50.71    | -0.09732  | 0.07026   | 1.075     | 0.8653    |
# | 176       | -1.026e+0 | -0.03363  | 0.07932   | 0.6676    | 1.21      |
# | 177       | -1.631e+0 | -0.034    | 0.2921    | 2.833     | 1.196     |
# | 178       | -144.5    | -0.02526  | -0.0202   | 0.9877    | 1.318     |
# | 179       | -116.2    | 0.156     | -0.06395  | 1.14      | 0.8257    |
# | 180       | -2.157e+0 | -0.2496   | 0.03246   | 3.0       | 1.566     |
# | 181       | -373.6    | -0.09097  | -0.05565  | 1.36      | 0.7861    |
# | 182       | -2.19e+04 | 0.4943    | 0.3916    | 2.529     | 1.116     |
# | 183       | -1.378e+0 | 0.2041    | -0.2051   | 1.468     | 0.8569    |
# | 184       | -498.8    | 0.2181    | 0.02708   | 0.7766    | 0.9623    |
# | 185       | -96.83    | 0.08065   | -0.09381  | 0.9432    | 1.22      |
# | 186       | -281.7    | -0.2015   | -0.01256  | 0.9202    | 1.112     |
# | 187       | -46.24    | 0.06127   | 0.09597   | 1.049     | 1.177     |
# | 188       | -679.8    | 0.1035    | 0.04091   | 1.601     | 0.9786    |
# | 189       | -719.7    | -0.07565  | 0.06401   | 1.404     | 0.7174    |
# | 190       | -44.65    | -0.1112   | -0.03355  | 1.173     | 0.9682    |
# | 191       | -255.9    | 0.06605   | 0.08874   | 1.017     | 0.7106    |
# | 192       | -15.49    | -0.04179  | -0.04787  | 1.012     | 1.129     |
# | 193       | -345.9    | 0.007405  | -0.172    | 1.239     | 1.228     |
# | 194       | -175.2    | -0.122    | -0.04649  | 1.277     | 0.8689    |
# | 195       | -16.3     | 0.06616   | -0.07592  | 1.18      | 0.9982    |
# | 196       | -245.3    | 0.1793    | -0.08999  | 1.293     | 1.063     |
# | 197       | -360.0    | 0.19      | -0.2055   | 1.031     | 0.999     |
# | 198       | -574.9    | 0.1547    | -0.06659  | 1.245     | 0.7113    |
# | 199       | -3.388e+0 | -0.239    | 0.07984   | 1.017     | 1.747     |
# | 200       | -93.99    | -0.07593  | 0.1026    | 0.8635    | 0.9708    |
# | 201       | -1.025e+0 | -0.2194   | 0.08515   | 1.487     | 0.8875    |
# | 202       | -21.36    | 0.08665   | -0.0952   | 1.065     | 1.062     |
# | 203       | -537.6    | 0.04306   | -0.03352  | 0.702     | 1.178     |
# | 204       | -138.6    | 0.05974   | -0.183    | 1.153     | 1.093     |
# | 205       | -43.34    | -0.1001   | -0.06511  | 1.138     | 1.063     |
# | 206       | -59.89    | 0.1292    | 0.125     | 1.124     | 0.9978    |
# | 207       | -129.2    | 0.1304    | 0.124     | 0.9043    | 1.087     |
# | 208       | -42.91    | 0.01312   | -0.04767  | 0.905     | 1.153     |
# | 209       | -210.7    | 0.1237    | 0.1014    | 0.8666    | 1.191     |
# | 210       | -35.08    | -0.0331   | 0.04348   | 1.108     | 0.8211    |
# | 211       | -1.087e+0 | 0.2845    | 0.05643   | 0.8635    | 1.29      |
# | 212       | -49.26    | 0.1646    | -0.06321  | 1.115     | 0.9602    |
# | 213       | -6.268e+0 | 0.002015  | 0.1415    | 2.123     | 0.6751    |
# | 214       | -3.505e+0 | -0.009559 | 0.1789    | 1.992     | 0.977     |
# | 215       | -1.182e+0 | 0.5307    | -1.163    | 2.785     | 2.997     |
# | 216       | -23.26    | -0.08646  | -0.07983  | 1.028     | 1.033     |
# | 217       | -262.5    | 0.1532    | -0.08567  | 1.134     | 0.7611    |
# | 218       | -1.935e+0 | -0.03408  | 0.3963    | 1.504     | 2.709     |
# | 219       | -7.582e+0 | -0.005394 | -0.02248  | 2.438     | 1.218     |
# | 220       | -21.02    | 0.009696  | -0.09335  | 1.052     | 1.126     |
# | 221       | -178.5    | 0.01904   | 0.2201    | 1.05      | 1.016     |
# | 222       | -3.795e+0 | 0.7164    | -0.3202   | 1.282     | 2.354     |
# | 223       | -1.464e+0 | 0.5326    | 0.1689    | 2.045     | 1.594     |
# | 224       | -2.348e+0 | -0.1227   | -0.1346   | 1.586     | 0.6911    |
# | 225       | -489.9    | 0.03883   | -0.2363   | 0.8569    | 0.8988    |
# | 226       | -51.29    | 0.1517    | -0.03585  | 0.9128    | 0.9695    |
# | 227       | -304.5    | 0.1714    | -0.07663  | 1.019     | 1.292     |
# | 228       | -54.63    | 0.03699   | -0.1323   | 0.9083    | 0.9363    |
# | 229       | -992.7    | -0.08465  | -0.06823  | 1.646     | 0.9043    |
# | 230       | -650.1    | 0.08615   | 0.2588    | 0.8293    | 1.013     |
# | 231       | -105.5    | 0.1202    | -0.1172   | 0.9192    | 1.128     |
# | 232       | -53.6     | 0.04975   | -0.1396   | 0.9111    | 0.9473    |
# | 233       | -2.788e+0 | -0.06213  | -0.3605   | 0.9228    | 1.522     |
# | 234       | -43.39    | 0.009851  | 0.1315    | 1.135     | 0.8928    |
# | 235       | -77.65    | 0.05945   | -0.03538  | 0.8944    | 0.8077    |
# | 236       | -157.8    | 0.1716    | -0.02618  | 1.026     | 1.208     |
# | 237       | -1.217e+0 | 0.03966   | -0.1175   | 1.118     | 1.626     |
# | 238       | -118.4    | 0.03892   | -0.1637   | 0.8952    | 1.036     |
# | 239       | -51.51    | -0.005167 | -0.1452   | 1.06      | 0.9035    |
# | 240       | -891.9    | 0.1635    | -0.22     | 1.41      | 1.024     |
# | 241       | -110.2    | -0.09517  | -0.08841  | 1.259     | 0.9476    |
# | 242       | -5.465    | 0.006777  | 0.06264   | 0.9443    | 0.9975    |
# | 243       | -276.1    | -0.1085   | -0.168    | 1.238     | 1.074     |
# | 244       | -1.817e+0 | 0.1722    | -0.3056   | 0.765     | 1.089     |
# | 245       | -118.3    | 0.09451   | -0.1397   | 0.8889    | 0.9456    |
# | 246       | -645.0    | 0.1138    | -0.06674  | 1.579     | 0.9818    |
# | 247       | -173.0    | 0.2321    | -0.04241  | 1.024     | 1.061     |
# | 248       | -137.7    | 0.02853   | 0.01408   | 1.382     | 1.065     |
# | 249       | -2.064e+0 | -0.05491  | 0.07364   | 1.738     | 0.7365    |
# | 250       | -128.5    | 0.003043  | -0.05219  | 1.201     | 0.7711    |
# | 251       | -517.7    | 0.1281    | 0.05304   | 1.454     | 1.182     |
# | 252       | -849.2    | 0.0819    | -0.2812   | 0.9684    | 1.268     |
# | 253       | -1.73e+03 | -0.05793  | -0.2379   | 1.458     | 1.342     |
# | 254       | -62.47    | -0.06842  | 0.1143    | 1.176     | 0.9242    |
# | 255       | -655.2    | -0.1113   | -0.1628   | 1.433     | 0.9705    |
# | 256       | -36.37    | -0.1029   | 0.0139    | 0.9694    | 0.8816    |
# | 257       | -92.73    | -0.05229  | -0.1234   | 0.8597    | 0.9803    |
# | 258       | -4.108e+0 | -0.717    | 1.59      | 0.1       | 3.0       |
# | 259       | -76.15    | -0.007159 | 0.08087   | 0.862     | 0.8492    |
# | 260       | -17.06    | 0.01675   | -0.06115  | 1.189     | 1.056     |
# | 261       | -301.3    | -0.1708   | 0.08958   | 1.06      | 0.7945    |
# | 262       | -81.69    | -0.01029  | 0.07088   | 0.8103    | 0.932     |
# | 263       | -1.078e+0 | 0.1185    | -0.124    | 1.005     | 0.6228    |
# | 264       | -1.432e+0 | -0.4943   | 0.1584    | 2.386     | 0.7947    |
# | 265       | -6.921e+0 | 0.6125    | 0.8336    | 1.823     | 3.0       |
# | 266       | -1.161e+0 | -0.1084   | -0.3146   | 1.155     | 1.157     |
# | 267       | -137.0    | 0.01292   | 0.07629   | 1.012     | 1.299     |
# | 268       | -4.593e+0 | 0.1847    | -0.1196   | 1.101     | 2.013     |
# | 269       | -479.0    | 0.03411   | 0.02899   | 1.045     | 0.6447    |
# | 270       | -852.4    | 0.211     | -0.1189   | 0.8032    | 0.7892    |
# | 271       | -168.1    | 0.2228    | 0.04693   | 1.003     | 1.09      |
# | 272       | -72.49    | 0.0457    | 0.05658   | 1.177     | 1.197     |
# | 273       | -85.62    | -0.009167 | -0.08452  | 0.8237    | 0.9134    |
# | 274       | -10.01    | -0.04754  | -0.09384  | 1.028     | 0.9594    |
# | 275       | -1.017e+0 | -0.2511   | -0.2809   | 1.028     | 2.191     |
# | 276       | -8.335e+0 | -0.4639   | 0.1466    | 1.804     | 0.7004    |
# | 277       | -57.66    | 0.1139    | 0.03833   | 0.9985    | 0.8067    |
# | 278       | -419.4    | 0.2289    | 0.008441  | 1.361     | 1.03      |
# | 279       | -219.9    | -0.01069  | 0.1755    | 0.9428    | 1.225     |
# | 280       | -255.3    | 0.1036    | -0.06163  | 1.423     | 0.9636    |
# | 281       | -901.2    | 0.2168    | -0.2513   | 1.2       | 0.9888    |
# | 282       | -552.3    | 0.2153    | 0.09108   | 0.809     | 0.8424    |
# | 283       | -255.3    | 0.1219    | 0.02054   | 0.8564    | 1.262     |
# | 284       | -4.728e+0 | 0.1453    | 0.02287   | 2.211     | 0.9231    |
# | 285       | -83.98    | 0.0182    | 0.03256   | 1.284     | 1.135     |
# | 286       | -597.7    | 0.08794   | -0.2643   | 0.9772    | 0.8495    |
# | 287       | -120.9    | 0.05456   | -0.02881  | 1.287     | 1.178     |
# | 288       | -1.08e+03 | -0.08062  | -0.1296   | 1.184     | 0.644     |
# | 289       | -369.2    | 0.1006    | -0.04521  | 1.451     | 1.114     |
# | 290       | -434.2    | 0.1056    | -0.1524   | 1.249     | 1.276     |
# | 291       | -1.729e+0 | 0.1151    | 0.1458    | 0.6158    | 0.9386    |
# | 292       | -3.358e+0 | 0.7214    | -0.2589   | 2.955     | 1.396     |
# | 293       | -19.33    | 0.0707    | 0.05622   | 0.9385    | 0.8739    |
# | 294       | -562.5    | -0.1723   | -0.1022   | 1.179     | 1.3       |
# | 295       | -120.0    | 0.2083    | 0.02351   | 0.9408    | 0.9636    |
# | 296       | -25.19    | -0.09002  | -0.02944  | 0.9651    | 0.8888    |
# | 297       | -57.7     | 0.009449  | -0.08163  | 1.026     | 0.7891    |
# | 298       | -206.3    | 0.03911   | 0.04795   | 0.7761    | 1.143     |
# | 299       | -125.3    | -0.09346  | 0.1501    | 1.038     | 0.8868    |
# | 300       | -408.2    | -0.1839   | 0.1051    | 1.197     | 0.8201    |
# | 301       | -604.5    | 0.002059  | -0.03834  | 1.526     | 1.162     |
# | 302       | -112.8    | 0.1461    | -0.06257  | 0.9119    | 0.8381    |
# | 303       | -309.3    | -0.1921   | 0.1382    | 1.13      | 0.9963    |
# | 304       | -353.7    | -0.187    | 0.02616   | 1.316     | 1.086     |
# | 305       | -356.3    | 0.236     | 0.1016    | 0.9489    | 1.128     |
# | 306       | -195.2    | -0.1621   | -0.03171  | 1.049     | 0.801     |
# | 307       | -801.9    | -0.1233   | 0.2881    | 1.079     | 1.075     |
# | 308       | -68.46    | -0.06913  | -0.1129   | 1.093     | 0.8751    |
# | 309       | -1.01e+03 | -0.1084   | -0.2757   | 0.8971    | 1.226     |
# | 310       | -96.26    | 0.07523   | 0.03075   | 1.075     | 0.7539    |
# | 311       | -209.9    | 0.05801   | -0.06356  | 1.045     | 1.355     |
# | 312       | -146.9    | 0.02415   | -0.09431  | 1.127     | 0.7645    |
# | 313       | -538.6    | -0.1598   | -0.1214   | 0.9713    | 1.322     |
# | 314       | -2.16e+03 | 0.1438    | -0.2257   | 0.6845    | 1.283     |
# | 315       | -0.6504   | 0.01522   | -0.04955  | 0.9833    | 1.007     |
# | 316       | -118.4    | 0.1068    | -0.05368  | 1.032     | 0.7649    |
# | 317       | -413.8    | 0.2367    | -0.03153  | 0.9057    | 0.7948    |
# | 318       | -567.0    | -0.209    | -0.0668   | 0.9207    | 1.241     |
# | 319       | -744.9    | 0.04181   | 0.2361    | 1.22      | 1.315     |
# | 320       | -587.5    | 0.1306    | -0.1967   | 1.348     | 0.8994    |
# | 321       | -433.9    | 0.1105    | -0.2071   | 0.8788    | 0.856     |
# | 322       | -819.6    | 0.1626    | 0.06284   | 0.8051    | 0.7048    |
# | 323       | -2.159e+0 | -0.1377   | 0.1023    | 0.6077    | 0.8596    |
# | 324       | -222.0    | 0.1139    | 0.0328    | 0.7616    | 1.014     |
# | 325       | -593.7    | 0.07792   | -0.1338   | 0.8101    | 1.327     |
# | 326       | -529.3    | 0.1339    | -0.1409   | 1.189     | 0.742     |
# | 327       | -2.628e+0 | 0.3072    | 0.1715    | 1.449     | 0.7121    |
# | 328       | -361.9    | 0.1471    | -0.1654   | 0.8822    | 1.176     |
# | 329       | -263.4    | 0.1896    | -0.08915  | 1.301     | 0.9666    |
# | 330       | -386.3    | -0.008567 | -0.1013   | 1.231     | 1.36      |
# | 331       | -67.29    | -0.02664  | -0.1639   | 1.012     | 1.016     |
# | 332       | -995.8    | -0.1606   | -0.2649   | 0.8925    | 0.9353    |
# | 333       | -34.79    | 0.1121    | 0.1141    | 1.034     | 0.9451    |
# | 334       | -680.4    | -0.01271  | 0.2621    | 1.293     | 1.124     |
# | 335       | -72.49    | -0.1344   | -0.03605  | 1.197     | 0.9794    |
# | 336       | -1.044e+0 | -5.0      | -1.179    | 3.0       | 3.0       |
# | 337       | -367.0    | 0.1885    | -0.05218  | 1.302     | 0.8218    |
# | 338       | -243.5    | -0.06424  | -0.2047   | 1.145     | 1.106     |
# | 339       | -5.73     | 0.0144    | 0.04017   | 1.034     | 0.8602    |
# | 340       | -2.693e+0 | -0.1484   | 0.2007    | 0.7304    | 1.445     |
# | 341       | -8.331    | 0.06357   | -0.06976  | 1.098     | 0.9165    |
# | 342       | -15.44    | 0.03887   | 0.08039   | 1.066     | 0.8622    |
# | 343       | -2.393e+0 | 0.1315    | 0.1515    | 1.071     | 1.772     |
# | 344       | -219.8    | -0.1649   | -0.06684  | 1.255     | 1.078     |
# | 345       | -179.5    | -0.07476  | -0.1857   | 1.07      | 1.149     |
# | 346       | -775.6    | -0.06087  | 0.2609    | 1.108     | 1.301     |
# | 347       | -275.9    | -0.1039   | -0.09515  | 0.7985    | 1.08      |
# | 348       | -196.9    | 0.0005259 | 0.1348    | 1.327     | 1.082     |
# | 349       | -325.0    | -0.1729   | -0.1329   | 1.218     | 0.9635    |
# | 350       | -1.793e+0 | -0.3101   | -0.2124   | 1.026     | 0.8839    |
# | 351       | -426.7    | 0.1733    | 0.1363    | 1.274     | 0.8086    |
# | 352       | -432.3    | -0.006529 | -0.2539   | 1.185     | 1.08      |
# | 353       | -48.75    | 0.04815   | 0.09073   | 0.9499    | 0.8348    |
# | 354       | -893.9    | -0.2428   | 0.001958  | 0.8511    | 0.7884    |
# | 355       | -275.3    | -0.03219  | 0.223     | 1.068     | 1.144     |
# | 356       | -346.8    | 0.05285   | 0.125     | 0.757     | 0.8644    |
# | 357       | -971.6    | -0.3273   | -0.05367  | 1.119     | 0.9967    |
# | 358       | -203.4    | 0.08377   | -0.06736  | 0.9337    | 0.7396    |
# | 359       | -196.5    | -0.1295   | 0.1442    | 0.9109    | 0.9443    |
# | 360       | -1.719e+0 | 0.2951    | -0.104    | 1.603     | 1.063     |
# | 361       | -1.272e+0 | -0.1678   | -0.2071   | 0.7385    | 1.027     |
# | 362       | -3.106e+0 | -0.1665   | -0.5831   | 1.526     | 2.963     |
# | 363       | -240.9    | 0.09857   | 0.1722    | 0.8636    | 0.8696    |
# | 364       | -739.0    | 0.1628    | -0.005849 | 1.401     | 1.301     |
# | 365       | -314.7    | -0.133    | -0.1736   | 1.221     | 1.043     |
# | 366       | -519.5    | -0.01365  | -0.1576   | 0.7263    | 0.9776    |
# | 367       | -5.734e+0 | -0.2568   | 0.02196   | 2.192     | 0.9204    |
# | 368       | -438.5    | -0.04412  | 0.001685  | 1.492     | 0.8392    |
# | 369       | -965.2    | 0.2647    | -0.1644   | 0.8527    | 1.129     |
# | 370       | -162.0    | -0.1476   | -0.02785  | 1.011     | 0.7963    |
# | 371       | -126.9    | 0.05375   | 0.05609   | 0.8468    | 1.191     |
# | 372       | -3.849e+0 | 0.1088    | 0.3221    | 0.635     | 1.245     |
# | 373       | -143.5    | 0.1365    | -0.1495   | 0.9153    | 0.9992    |
# | 374       | -18.52    | 0.07201   | -0.03648  | 1.21      | 0.9972    |
# | 375       | -152.9    | -0.02856  | 0.0853    | 1.134     | 1.278     |
# | 376       | -1.003e+0 | 0.2711    | 0.2372    | 1.074     | 1.149     |
# | 377       | -5.421e+0 | 0.2619    | -0.3122   | 1.81      | 0.979     |
# | 378       | -1.636e+0 | 0.06718   | -0.1524   | 1.726     | 1.075     |
# | 379       | -262.4    | -0.07223  | -0.1985   | 0.9629    | 1.159     |
# | 380       | -762.2    | -0.1941   | -0.1571   | 0.8206    | 0.8899    |
# | 381       | -523.6    | -0.005233 | 0.1849    | 1.358     | 1.173     |
# | 382       | -494.5    | 0.2207    | 0.01869   | 0.9314    | 1.287     |
# | 383       | -62.96    | 0.08482   | -0.09921  | 1.175     | 0.8868    |
# | 384       | -252.3    | 0.122     | -0.1576   | 1.225     | 0.8632    |
# | 385       | -142.7    | 0.1591    | 0.09021   | 0.8844    | 1.094     |
# | 386       | -120.6    | 0.05579   | 0.005458  | 0.7727    | 0.9482    |
# | 387       | -91.16    | -0.03419  | -0.1713   | 1.132     | 0.9989    |
# | 388       | -347.8    | 0.1483    | 0.006125  | 1.41      | 1.142     |
# | 389       | -651.3    | -0.00658  | -0.2168   | 0.7735    | 1.15      |
# | 390       | -64.68    | -0.003424 | 0.041     | 1.318     | 0.9686    |
# | 391       | -381.9    | 0.07733   | 0.2604    | 0.9755    | 1.015     |
# | 392       | -55.77    | 0.1022    | 0.02716   | 0.9305    | 0.8148    |
# | 393       | -395.5    | -0.1348   | 0.03177   | 1.178     | 1.328     |
# | 394       | -934.0    | 0.1312    | -0.2152   | 1.047     | 1.423     |
# | 395       | -38.75    | 0.06725   | -0.02251  | 0.8779    | 1.121     |
# | 396       | -1.623e+0 | 0.1877    | 0.1203    | 1.261     | 1.555     |
# | 397       | -1.357e+0 | 0.7191    | 0.04447   | 1.784     | 0.8891    |
# | 398       | -271.6    | -0.0635   | -0.01914  | 0.9811    | 0.6999    |
# | 399       | -1.041e+0 | -0.1984   | -0.000820 | 1.449     | 1.255     |
# | 400       | -630.3    | 0.2435    | 0.1076    | 1.246     | 0.7975    |
# | 401       | -9.249    | 0.00302   | 0.0356    | 1.203     | 0.9625    |
# | 402       | -221.2    | 0.2541    | -0.03371  | 1.045     | 0.956     |
# | 403       | -4.497e+0 | 0.8516    | -0.3218   | 2.427     | 1.835     |
# | 404       | -718.3    | 0.04073   | -0.0906   | 1.374     | 0.7103    |
# | 405       | -5.175    | 0.04637   | -0.07668  | 1.11      | 0.9854    |
# =========================================================================
# Final Result:  {'target': -0.650396355655987, 'params': {'m1_': 0.015218273555188233, 'm2_': -0.0495458123685788, 'v1_': 0.9833075665983492, 'v2_': 1.007154351558461}}
# |   iter    |  target   |    m1_    |    m2_    |    v1_    |    v2_    |
# -------------------------------------------------------------------------
# | 1         | -8.133e+0 | -3.353    | -1.417    | 2.361     | 0.6772    |
# | 2         | -3.085e+0 | -1.451    | 1.312     | 1.549     | 1.141     |
# | 3         | -1.423e+0 | 1.355     | 0.752     | 2.069     | 2.08      |
# | 4         | -1.161e+0 | -3.702    | 4.225     | 1.323     | 2.791     |
# | 5         | -1.137e+0 | -3.886    | 2.224     | 0.7738    | 2.962     |
# | 6         | -1.985e+0 | 0.754     | 1.152     | 1.664     | 0.4673    |
# | 7         | -3.957e+0 | 1.134     | 0.1342    | 0.1       | 2.092     |
# | 8         | -2.777e+0 | 0.6845    | 1.768     | 3.0       | 1.678     |
# | 9         | -4.099e+0 | 2.703     | -0.572    | 3.0       | 1.626     |
# | 10        | -7.995e+0 | 2.747     | 2.245     | 1.532     | 2.51      |
# | 11        | -1.727e+0 | 0.4226    | 0.2658    | 2.214     | 1.692     |
# | 12        | -5.446e+0 | 0.3756    | -0.3108   | 2.751     | 3.0       |
# | 13        | -9.461e+0 | 0.7386    | -4.569    | 2.574     | 2.988     |
# | 14        | -3.722e+0 | 0.3788    | 0.1432    | 2.987     | 2.154     |
# | 15        | -2.882e+0 | 0.24      | 0.2027    | 2.362     | 2.48      |
# | 16        | -4.615e+0 | 0.8011    | -0.3667   | 2.145     | 2.159     |
# | 17        | -3.689e+0 | 0.04076   | 0.06602   | 2.793     | 0.3704    |
# | 18        | -9.42e+03 | 0.1491    | -0.1104   | 2.392     | 1.373     |
# | 19        | -6.083e+0 | -0.2028   | -0.3336   | 1.877     | 0.2424    |
# | 20        | -1.232e+0 | 5.0       | -5.0      | 0.1       | 0.1       |
# | 21        | -1.206e+0 | 0.3285    | 0.03392   | 2.515     | 1.366     |
# | 22        | -6.506e+0 | 0.04554   | 0.1369    | 2.327     | 1.14      |
# | 23        | -5.187e+0 | -0.413    | 0.2269    | 2.432     | 0.313     |
# | 24        | -4.686e+0 | 0.1714    | 0.008399  | 2.194     | 1.044     |
# | 25        | -8.919e+0 | 0.968     | 0.2102    | 2.786     | 3.0       |
# | 26        | -1.232e+0 | -5.0      | -5.0      | 0.1       | 3.0       |
# | 27        | -4.941e+0 | 0.1266    | 0.04097   | 2.141     | 1.217     |
# | 28        | -7.084e+0 | -0.6069   | 0.3255    | 3.0       | 3.0       |
# | 29        | -1.912e+0 | 0.7202    | -0.2145   | 2.149     | 0.1       |
# | 30        | -2.183e+0 | -0.1654   | -0.3205   | 3.0       | 0.8577    |
# | 31        | -1.232e+0 | 5.0       | 5.0       | 3.0       | 0.1       |
# | 32        | -1.083e+0 | -0.4321   | -0.2607   | 2.069     | 0.8654    |
# | 33        | -4.263e+0 | -0.1742   | 0.1906    | 1.954     | 0.8645    |
# | 34        | -3.859e+0 | -0.1239   | -0.2395   | 1.866     | 1.196     |
# | 35        | -2.952e+0 | -0.1342   | -0.05383  | 1.965     | 0.9747    |
# | 36        | -3.11e+03 | -0.4249   | -0.08827  | 1.373     | 1.088     |
# | 37        | -1.268e+0 | -0.3639   | -0.3025   | 1.506     | 1.952     |
# | 38        | -2.574e+0 | -0.2948   | -0.06859  | 1.581     | 1.264     |
# | 39        | -5.551e+0 | -0.5817   | -0.8701   | 0.887     | 1.401     |
# | 40        | -6.005e+0 | -1.072    | 0.01613   | 0.1       | 0.1       |
# | 41        | -4.933e+0 | -0.4793   | -0.7127   | 1.419     | 3.0       |
# | 42        | -5.354e+0 | -0.6221   | -0.8352   | 1.683     | 1.781     |
# | 43        | -2.015e+0 | -0.1784   | 0.1251    | 1.373     | 3.0       |
# | 44        | -8.538e+0 | 0.112     | -0.1548   | 1.344     | 2.284     |
# | 45        | -3.762e+0 | -0.2813   | -0.3289   | 1.423     | 1.21      |
# | 46        | -1.448e+0 | -0.3644   | -0.2014   | 0.9869    | 2.311     |
# | 47        | -1.167e+0 | -0.2441   | 0.3607    | 1.349     | 2.132     |
# | 48        | -2.049e+0 | -0.1911   | 0.01481   | 1.771     | 1.115     |
# | 49        | -1.152e+0 | -0.1492   | -0.02468  | 1.457     | 2.428     |
# | 50        | -2.484e+0 | -0.1924   | -0.01374  | 1.241     | 1.687     |
# | 51        | -5.413e+0 | -0.1733   | -0.3063   | 1.251     | 1.839     |
# | 52        | -4.993e+0 | 0.3557    | -0.6811   | 3.0       | 1.16      |
# | 53        | -4.11e+03 | -0.006264 | 0.4498    | 1.305     | 1.384     |
# | 54        | -2.409e+0 | -0.1504   | 0.2907    | 1.481     | 1.258     |
# | 55        | -5.33e+03 | 0.02316   | 0.03792   | 1.355     | 2.076     |
# | 56        | -1.257e+0 | 0.2801    | 0.4785    | 1.613     | 1.744     |
# | 57        | -2.555e+0 | 0.2546    | -0.2588   | 1.54      | 3.0       |
# | 58        | -6.012e+0 | -0.3722   | -0.3202   | 1.557     | 1.003     |
# | 59        | -1.045e+0 | -0.2574   | 0.06838   | 1.2       | 1.31      |
# | 60        | -961.9    | -0.2436   | 0.00827   | 1.382     | 1.217     |
# | 61        | -2.927e+0 | -0.5343   | -0.9415   | 0.1       | 3.0       |
# | 62        | -4.074e+0 | -0.1516   | 0.2782    | 1.053     | 1.809     |
# | 63        | -2.256e+0 | -0.3567   | 0.07811   | 1.32      | 1.253     |
# | 64        | -1.213e+0 | -0.9633   | -0.7673   | 3.0       | 3.0       |
# | 65        | -1.517e+0 | 0.07621   | 0.1811    | 1.681     | 1.102     |
# | 66        | -6.799e+0 | 0.06623   | 1.251     | 1.136     | 2.791     |
# | 67        | -1.104e+0 | -0.1756   | 0.08345   | 1.396     | 1.342     |
# | 68        | -4.65e+05 | -0.5237   | -1.184    | 3.0       | 0.1       |
# | 69        | -1.687e+0 | 0.3973    | 0.0141    | 2.978     | 1.04      |
# | 70        | -1.382e+0 | -0.05852  | -0.005302 | 3.0       | 1.086     |
# | 71        | -1.057e+0 | 0.4343    | 5.0       | 0.1       | 3.0       |
# | 72        | -905.0    | -0.1275   | 0.09745   | 1.593     | 1.035     |
# | 73        | -7.383e+0 | -0.1029   | -0.1827   | 2.334     | 0.8841    |
# | 74        | -1.232e+0 | -5.0      | 5.0       | 3.0       | 0.1       |
# | 75        | -4.801e+0 | 0.2433    | 0.7897    | 1.81      | 2.984     |
# | 76        | -1.23e+03 | -0.1482   | 0.166     | 1.24      | 1.441     |
# | 77        | -2.15e+04 | -0.1233   | 0.6143    | 1.04      | 2.647     |
# | 78        | -1.198e+0 | 5.0       | -5.0      | 3.0       | 3.0       |
# | 79        | -1.508e+0 | 0.07613   | -0.2854   | 1.925     | 2.126     |
# | 80        | -8.4e+03  | 0.03342   | 0.4689    | 1.233     | 1.984     |
# | 81        | -1.202e+0 | -0.03601  | 0.01086   | 1.69      | 1.145     |
# | 82        | -4.697e+0 | -0.3275   | -0.2453   | 1.3       | 1.517     |
# | 83        | -3.746e+0 | 0.0972    | -0.1184   | 1.701     | 1.568     |
# | 84        | -2.01e+03 | 0.1885    | -0.02959  | 1.589     | 1.42      |
# | 85        | -591.6    | 0.01146   | -0.04585  | 1.563     | 1.115     |
# | 86        | -2.6e+03  | 0.07014   | -0.2252   | 1.339     | 1.64      |
# | 87        | -3.403e+0 | -0.2118   | -0.3854   | 2.768     | 2.053     |
# | 88        | -5.607e+0 | -0.6627   | 0.5404    | 1.099     | 2.895     |
# | 89        | -693.2    | 0.001738  | 0.09302   | 1.392     | 1.352     |
# | 90        | -444.6    | -0.07346  | -0.05993  | 1.388     | 1.241     |
# | 91        | -924.8    | 0.04606   | 0.05945   | 1.33      | 1.47      |
# | 92        | -3.606e+0 | -0.2966   | -0.1961   | 2.072     | 3.0       |
# | 93        | -625.1    | -0.00178  | 0.001304  | 1.61      | 0.9779    |
# | 94        | -275.0    | -0.02333  | -0.1331   | 1.061     | 1.318     |
# | 95        | -414.5    | -0.09084  | -0.1351   | 1.152     | 1.333     |
# | 96        | -85.33    | -0.02131  | -0.007897 | 1.234     | 1.166     |
# | 97        | -214.5    | 0.01325   | 0.1908    | 1.192     | 1.094     |
# | 98        | -2.171e+0 | -0.1594   | 0.08535   | 1.653     | 0.7254    |
# | 99        | -5.077e+0 | -0.05249  | -0.3761   | 0.897     | 1.802     |
# | 100       | -260.9    | -0.03675  | 0.1539    | 1.3       | 1.127     |
# | 101       | -948.4    | -0.05561  | -0.06917  | 1.013     | 1.581     |
# | 102       | -4.522e+0 | 0.1989    | -0.4259   | 1.18      | 1.486     |
# | 103       | -436.6    | -0.1065   | 0.05812   | 0.9628    | 1.383     |
# | 104       | -3.972e+0 | 0.2032    | -0.9288   | 1.365     | 2.381     |
# | 105       | -217.6    | -0.1239   | -0.02555  | 1.372     | 0.956     |
# | 106       | -9.351e+0 | -1.394    | 0.1747    | 2.947     | 1.551     |
# | 107       | -2.219e+0 | -0.09136  | -0.3544   | 1.01      | 1.435     |
# | 108       | -1.246e+0 | -0.06895  | 0.3059    | 0.9994    | 1.367     |
# | 109       | -5.308e+0 | -1.055    | -0.06984  | 1.932     | 1.569     |
# | 110       | -1.027e+0 | -5.0      | -0.7675   | 3.0       | 3.0       |
# | 111       | -462.7    | 0.02867   | -0.2104   | 1.294     | 1.176     |
# | 112       | -207.1    | -0.0373   | 0.135     | 1.1       | 1.282     |
# | 113       | -140.2    | -0.09514  | 0.1165    | 1.158     | 1.146     |
# | 114       | -287.9    | 0.07995   | -0.2151   | 1.178     | 1.1       |
# | 115       | -702.9    | -0.1192   | -0.04617  | 1.582     | 0.9189    |
# | 116       | -105.4    | 0.03551   | 0.1366    | 1.239     | 0.9204    |
# | 117       | -38.57    | 0.1507    | 0.0597    | 0.9835    | 1.052     |
# | 118       | -1.232e+0 | -5.0      | -5.0      | 3.0       | 0.1       |
# | 119       | -8.762e+0 | 0.02936   | 0.06825   | 2.561     | 0.8165    |
# | 120       | -3.233    | 0.07934   | 0.01093   | 1.093     | 1.059     |
# | 121       | -21.68    | 0.06628   | 0.07377   | 1.018     | 1.142     |
# | 122       | -35.2     | 0.1441    | 0.04075   | 1.169     | 1.023     |
# | 123       | -244.6    | 0.1194    | 0.1058    | 1.377     | 0.9635    |
# | 124       | -53.89    | 0.02284   | 0.04021   | 1.299     | 0.9746    |
# | 125       | -1.214e+0 | 0.138     | 0.3182    | 0.9591    | 1.248     |
# | 126       | -121.1    | 0.1183    | 0.163     | 1.062     | 1.092     |
# | 127       | -252.3    | -0.01514  | -0.2236   | 1.115     | 1.079     |
# | 128       | -27.84    | 0.07179   | -0.08733  | 1.048     | 1.133     |
# | 129       | -706.9    | 0.06828   | 0.2793    | 0.9074    | 1.204     |
# | 130       | -6.453    | 0.03769   | -0.03547  | 1.156     | 1.014     |
# | 131       | -156.0    | 0.0532    | 0.1453    | 0.9765    | 1.223     |
# | 132       | -1.52e+03 | 0.09329   | -0.3623   | 1.152     | 1.15      |
# | 133       | -484.1    | -0.07017  | -0.1956   | 1.359     | 0.9439    |
# | 134       | -1.701e+0 | 0.2141    | 0.1266    | 1.195     | 1.559     |
# | 135       | -127.6    | 0.07016   | -0.06837  | 1.339     | 1.007     |
# | 136       | -1.519e+0 | 0.215     | -0.1992   | 1.433     | 1.271     |
# | 137       | -889.4    | 0.07651   | 0.2079    | 1.098     | 1.452     |
# | 138       | -127.3    | 0.05361   | 0.001047  | 1.387     | 0.9681    |
# | 139       | -17.06    | 0.07913   | 0.1065    | 1.057     | 1.044     |
# | 140       | -366.4    | -0.01653  | -0.2471   | 1.184     | 1.008     |
# | 141       | -644.8    | 0.05467   | 0.1125    | 0.9539    | 1.485     |
# | 142       | -2.609e+0 | 0.007331  | -0.004319 | 0.9633    | 1.9       |
# | 143       | -367.3    | 0.2301    | -0.04169  | 1.11      | 1.241     |
# | 144       | -30.64    | 0.1269    | 0.03524   | 1.04      | 1.131     |
# | 145       | -22.15    | 0.1163    | -0.05178  | 1.1       | 1.066     |
# | 146       | -274.4    | -0.08499  | 0.06332   | 1.095     | 1.334     |
# | 147       | -3.047e+0 | 0.2723    | -0.1587   | 1.405     | 1.538     |
# | 148       | -122.9    | -0.08795  | -0.1149   | 1.225     | 1.067     |
# | 149       | -2.949e+0 | 0.01571   | 0.3855    | 1.448     | 0.9908    |
# | 150       | -84.18    | 0.08726   | -0.01398  | 0.9843    | 1.251     |
# | 151       | -466.9    | 0.1936    | 0.1052    | 1.352     | 0.861     |
# | 152       | -657.7    | 0.05622   | 0.01897   | 1.475     | 0.7514    |
# | 153       | -179.6    | 0.08842   | -0.04477  | 0.9198    | 1.289     |
# | 154       | -24.08    | 0.1333    | 0.009124  | 1.105     | 0.8899    |
# | 155       | -71.93    | 0.07861   | 0.001012  | 1.273     | 0.8708    |
# | 156       | -2.704e+0 | -0.192    | -0.05509  | 0.8681    | 1.701     |
# | 157       | -31.19    | 0.1356    | 0.0481    | 1.158     | 0.9406    |
# | 158       | -255.1    | 0.02381   | 0.07455   | 1.406     | 0.8583    |
# | 159       | -1.254e+0 | 0.3567    | -0.006431 | 1.38      | 1.072     |
# | 160       | -2.84e+03 | 0.3352    | -0.3012   | 1.079     | 1.242     |
# | 161       | -126.5    | 0.1948    | -0.09442  | 1.119     | 0.9818    |
# | 162       | -41.47    | 0.1164    | -0.03555  | 1.2       | 0.93      |
# | 163       | -2.604e+0 | -0.9182   | 1.792     | 3.0       | 3.0       |
# | 164       | -198.0    | 0.2274    | 0.02844   | 1.175     | 1.09      |
# | 165       | -35.39    | 0.1603    | 0.0366    | 1.097     | 0.9838    |
# | 166       | -355.8    | 0.01827   | 0.2546    | 1.106     | 0.9141    |
# | 167       | -511.8    | -0.1699   | -0.1995   | 1.124     | 1.129     |
# | 168       | -468.9    | -0.04074  | -0.1028   | 0.9251    | 1.403     |
# | 169       | -1.76e+05 | 1.008     | -1.271    | 3.0       | 3.0       |
# | 170       | -48.51    | 0.1096    | 0.1204    | 1.007     | 1.094     |
# | 171       | -105.5    | 0.2006    | 0.03995   | 1.025     | 0.8835    |
# | 172       | -844.5    | 0.3293    | 0.05959   | 0.9576    | 1.113     |
# | 173       | -877.9    | 0.1121    | -0.254    | 0.8537    | 1.241     |
# | 174       | -236.9    | 0.1787    | 0.1771    | 1.071     | 0.9496    |
# | 175       | -20.75    | 0.0317    | 0.1312    | 1.055     | 0.9434    |
# | 176       | -71.97    | -0.1043   | -0.05055  | 1.14      | 1.133     |
# | 177       | -130.0    | 0.1851    | -0.1004   | 0.9671    | 1.08      |
# | 178       | -218.1    | 0.1804    | 0.02333   | 1.213     | 1.202     |
# | 179       | -1.266e+0 | 0.1868    | -0.1253   | 1.584     | 0.8884    |
# | 180       | -1.495e+0 | 0.2696    | -0.2436   | 0.8658    | 1.03      |
# | 181       | -125.1    | 0.03669   | 0.2035    | 1.072     | 1.032     |
# | 182       | -247.9    | 0.09554   | -0.08747  | 1.273     | 1.237     |
# | 183       | -94.64    | 0.2075    | -0.0113   | 0.998     | 0.9995    |
# | 184       | -453.7    | 0.2215    | 0.105     | 0.8252    | 1.004     |
# | 185       | -532.5    | -0.03788  | -0.2606   | 1.119     | 0.8895    |
# | 186       | -1.924e+0 | -0.3087   | 0.2091    | 1.345     | 1.007     |
# | 187       | -377.3    | 0.174     | -0.02602  | 1.436     | 0.999     |
# | 188       | -1.423e+0 | -0.549    | -0.01634  | 2.227     | 1.351     |
# | 189       | -58.18    | 0.09187   | -0.1434   | 0.9899    | 0.9699    |
# | 190       | -87.03    | 0.1214    | 0.1494    | 0.9706    | 0.9987    |
# | 191       | -601.6    | -0.1239   | 0.2671    | 1.03      | 0.993     |
# | 192       | -555.6    | 0.1128    | -0.05107  | 0.7011    | 1.077     |
# | 193       | -92.12    | 0.09899   | -0.02618  | 0.8318    | 1.091     |
# | 194       | -1.081e+0 | 0.123     | 0.1402    | 0.7927    | 1.402     |
# | 195       | -273.9    | 0.1697    | -0.000367 | 1.331     | 0.8445    |
# | 196       | -662.2    | 0.08919   | -0.1584   | 1.028     | 1.445     |
# | 197       | -205.4    | 0.1122    | 0.03584   | 0.8091    | 1.174     |
# | 198       | -117.6    | 0.1602    | -0.04078  | 0.8602    | 1.01      |
# | 199       | -228.8    | 0.007059  | 0.04666   | 0.8233    | 1.256     |
# | 200       | -21.91    | -0.09736  | -0.01089  | 1.058     | 0.9021    |
# | 201       | -175.3    | 0.1538    | -0.04344  | 0.8294    | 1.09      |
# | 202       | -42.54    | -0.1032   | 0.06314   | 1.144     | 0.9655    |
# | 203       | -2.841e+0 | 0.3095    | 0.09327   | 1.757     | 1.157     |
# | 204       | -174.1    | -0.1463   | -0.00908  | 1.225     | 1.133     |
# | 205       | -22.72    | -0.02372  | -0.08564  | 1.137     | 0.9056    |
# | 206       | -31.2     | -0.07196  | 0.1089    | 1.051     | 1.024     |
# | 207       | -415.5    | -0.08601  | -0.1405   | 1.315     | 0.8168    |
# | 208       | -5.518    | -0.02552  | -0.07835  | 1.08      | 0.9507    |
# | 209       | -2.403e+0 | 0.1022    | -0.1102   | 1.097     | 1.807     |
# | 210       | -1.307e+0 | 0.2419    | 0.0177    | 0.9725    | 0.6404    |
# | 211       | -157.3    | 0.1455    | -0.04884  | 0.995     | 0.7816    |
# | 212       | -3.774e+0 | 0.3733    | 0.1913    | 0.8642    | 0.7196    |
# | 213       | -311.4    | 0.222     | 0.01526   | 0.9016    | 0.8282    |
# | 214       | -46.88    | -0.004963 | -0.1221   | 0.9214    | 1.086     |
# | 215       | -3.158e+0 | -0.4059   | 0.3338    | 2.999     | 0.6451    |
# | 216       | -5.777    | -0.05851  | -0.04051  | 1.055     | 1.021     |
# | 217       | -264.4    | 0.1221    | 0.05918   | 1.245     | 1.265     |
# | 218       | -1.513e+0 | 0.2056    | -0.6103   | 1.029     | 0.747     |
# | 219       | -70.77    | -0.09739  | -0.0182   | 1.253     | 0.9416    |
# | 220       | -1.591e+0 | -0.03807  | 0.2446    | 0.768     | 1.368     |
# | 221       | -45.35    | 0.02018   | 0.09865   | 1.229     | 0.9338    |
# | 222       | -528.9    | -0.03801  | -0.07876  | 1.172     | 0.6697    |
# | 223       | -1.535e+0 | 0.2587    | -0.2769   | 1.174     | 0.8803    |
# | 224       | -396.1    | 0.2316    | 0.01894   | 1.146     | 0.7735    |
# | 225       | -63.56    | 0.01388   | 0.03668   | 1.242     | 0.8408    |
# | 226       | -631.4    | 0.2397    | 0.08478   | 1.297     | 1.235     |
# | 227       | -248.7    | 0.1983    | 0.06281   | 0.8299    | 1.009     |
# | 228       | -99.97    | 0.1366    | -0.08168  | 0.859     | 1.025     |
# | 229       | -553.8    | 0.1778    | 0.02706   | 0.9585    | 1.391     |
# | 230       | -106.7    | 0.04548   | -0.0269   | 1.158     | 0.7582    |
# | 231       | -368.9    | -0.05694  | -0.2509   | 1.032     | 1.031     |
# | 232       | -551.2    | 0.1584    | -0.1102   | 1.433     | 1.121     |
# | 233       | -594.2    | -0.2713   | 0.03569   | 1.196     | 1.064     |
# | 234       | -329.7    | 0.08864   | -0.2008   | 1.246     | 1.116     |
# | 235       | -96.27    | 0.1067    | -0.08722  | 1.226     | 0.8739    |
# | 236       | -91.7     | -0.09078  | 0.1413    | 1.148     | 0.9651    |
# ...
# | 194       | -3.474e+0 | 0.2838    | 0.1593    | 1.316     | 1.641     |
# | 195       | -608.1    | -0.04868  | 0.2701    | 1.227     | 1.005     |
# | 196       | -1.347e+0 | 0.253     | -0.2193   | 1.38      | 0.9852    |
# | 197       | -1.71e+03 | -0.1077   | 0.2872    | 0.9487    | 1.452     |
# | 198       | -1.714e+0 | 0.07459   | 0.2982    | 0.9044    | 1.473     |
# | 199       | -150.3    | -0.09142  | 0.048     | 1.134     | 1.26      |
# | 200       | -319.1    | -0.0944   | 0.2024    | 0.9113    | 0.8762    |
# | 201       | -530.2    | -0.125    | 0.2503    | 1.021     | 1.011     |
# | 202       | -3.663e+0 | -0.1569   | 0.1977    | 1.939     | 1.038     |
# | 203       | -291.4    | -0.1139   | 0.01041   | 1.146     | 1.302     |
# | 204       | -160.1    | -0.1507   | -0.08672  | 0.9678    | 0.8625    |
# | 205       | -281.2    | -0.05222  | -0.07538  | 1.435     | 0.9989    |
# | 206       | -5.292e+0 | -0.1724   | -0.3284   | 0.6301    | 1.303     |
# | 207       | -965.8    | 0.1725    | 0.04879   | 1.586     | 0.8321    |
# | 208       | -153.1    | 0.1657    | 0.1559    | 1.007     | 0.9771    |
# | 209       | -173.8    | -0.08806  | -0.05337  | 0.8743    | 0.8017    |
# | 210       | -423.8    | -0.1955   | 0.1032    | 0.8552    | 1.077     |
# | 211       | -247.1    | 0.009278  | -0.2043   | 1.005     | 1.204     |
# | 212       | -77.73    | 0.1817    | -0.03568  | 1.194     | 0.9629    |
# | 213       | -2.502e+0 | -0.09965  | -0.1807   | 0.721     | 1.512     |
# | 214       | -966.5    | -0.2545   | -0.1894   | 1.002     | 0.9001    |
# | 215       | -221.9    | -0.1403   | -0.03531  | 1.025     | 1.265     |
# | 216       | -475.1    | 0.1575    | 0.1537    | 1.083     | 0.7408    |
# | 217       | -146.9    | -0.0369   | 0.07255   | 0.7955    | 1.077     |
# | 218       | -589.8    | 0.2423    | -0.1619   | 1.232     | 1.098     |
# | 219       | -1.156e+0 | 0.07477   | -0.2038   | 0.8038    | 1.396     |
# | 220       | -633.4    | 0.2638    | -0.09493  | 1.284     | 1.149     |
# | 221       | -247.2    | 0.06463   | 0.08329   | 1.01      | 1.362     |
# | 222       | -714.3    | -0.02148  | -0.2389   | 1.005     | 0.7622    |
# | 223       | -228.8    | -0.1661   | -0.1431   | 1.108     | 0.9785    |
# | 224       | -333.5    | -0.04331  | -0.1798   | 0.9486    | 0.7897    |
# | 225       | -239.6    | 0.1782    | 0.1321    | 0.9013    | 1.104     |
# | 226       | -501.7    | -0.0815   | 0.04675   | 1.524     | 0.9096    |
# | 227       | -475.3    | -0.1562   | -0.01512  | 0.8392    | 1.242     |
# | 228       | -76.75    | -0.1066   | 0.094     | 0.9163    | 0.9275    |
# | 229       | -353.6    | -0.01687  | 0.1947    | 1.132     | 0.7779    |
# | 230       | -256.1    | -0.01153  | 0.2078    | 0.8865    | 1.067     |
# | 231       | -299.1    | 0.1279    | 0.04647   | 1.413     | 0.8742    |
# | 232       | -330.2    | 0.1131    | -0.2095   | 1.101     | 1.197     |
# | 233       | -55.32    | 0.005226  | -0.08968  | 0.9514    | 1.191     |
# | 234       | -943.7    | -0.06161  | -0.2971   | 1.247     | 1.066     |
# | 235       | -254.4    | 0.1248    | 0.1933    | 1.151     | 1.095     |
# | 236       | -77.13    | -0.05479  | -0.1115   | 0.8896    | 1.071     |
# | 237       | -77.56    | 0.01098   | -0.1389   | 1.047     | 0.8537    |
# | 238       | -152.7    | -0.1276   | 0.07068   | 1.179     | 0.8389    |
# | 239       | -99.19    | -0.02193  | 0.08246   | 1.249     | 0.8407    |
# | 240       | -415.2    | 0.2711    | 0.1221    | 1.073     | 0.9613    |
# | 241       | -13.16    | 0.02376   | 0.04838   | 0.9714    | 0.8438    |
# | 242       | -525.5    | 0.06246   | 0.06327   | 1.348     | 1.357     |
# | 243       | -58.11    | -0.03056  | 0.08379   | 0.905     | 1.154     |
# | 244       | -235.7    | 0.1831    | 0.003012  | 0.9553    | 1.245     |
# | 245       | -81.88    | 0.1051    | 0.133     | 1.083     | 0.8452    |
# | 246       | -1.627e+0 | -0.006498 | 0.3886    | 0.991     | 0.9607    |
# | 247       | -399.7    | -0.06749  | -0.2461   | 0.9425    | 1.006     |
# | 248       | -198.9    | -0.06143  | -0.1028   | 1.053     | 1.311     |
# | 249       | -379.5    | -0.192    | 0.04864   | 1.195     | 1.2       |
# | 250       | -27.91    | -0.1098   | 0.01555   | 1.128     | 1.028     |
# | 251       | -140.0    | 0.1283    | 0.004248  | 1.135     | 0.7659    |
# | 252       | -469.5    | -0.2149   | 0.05122   | 0.8813    | 0.8605    |
# | 253       | -268.5    | 0.2028    | 0.1061    | 0.8871    | 1.109     |
# | 254       | -907.2    | 0.2831    | 0.03538   | 0.9915    | 1.332     |
# | 255       | -142.9    | -0.1186   | -0.139    | 0.9431    | 1.055     |
# | 256       | -450.9    | -0.02687  | -0.253    | 0.9954    | 1.203     |
# | 257       | -858.7    | 0.1626    | 0.1665    | 1.336     | 0.7593    |
# | 258       | -1.683e+0 | 0.3173    | -0.04813  | 1.58      | 0.8866    |
# | 259       | -48.3     | -0.03475  | 0.04716   | 1.03      | 1.209     |
# | 260       | -170.4    | 0.03766   | 0.1165    | 1.345     | 1.013     |
# | 261       | -239.1    | -0.02732  | -0.2043   | 1.172     | 1.106     |
# | 262       | -788.4    | -0.105    | 0.1684    | 1.27      | 1.346     |
# | 263       | -9.311e+0 | -0.008283 | -0.3936   | 0.6407    | 1.84      |
# | 264       | -616.8    | 0.1041    | -0.1209   | 1.518     | 0.9306    |
# | 265       | -27.95    | -0.02375  | -0.08633  | 0.9679    | 0.8566    |
# | 266       | -18.16    | 0.0869    | -0.08685  | 0.9557    | 1.034     |
# | 267       | -190.1    | 0.01122   | 0.0405    | 0.9613    | 1.339     |
# | 268       | -351.6    | -0.1154   | 0.09776   | 1.404     | 0.9415    |
# | 269       | -222.1    | 0.2274    | -0.03936  | 0.9825    | 0.8709    |
# | 270       | -6.805e+0 | 0.01348   | 0.0584    | 1.816     | 1.829     |
# | 271       | -194.9    | -0.01669  | 0.1659    | 1.097     | 1.22      |
# | 272       | -5.469    | -0.04777  | -0.01409  | 1.098     | 0.9085    |
# | 273       | -753.9    | -0.2127   | -0.06155  | 0.7816    | 0.8951    |
# | 274       | -388.0    | 0.1984    | 0.04645   | 1.131     | 0.7391    |
# | 275       | -1.848e+0 | -0.1102   | -0.3575   | 0.8728    | 0.9705    |
# | 276       | -653.5    | 0.03504   | -0.09989  | 0.745     | 1.282     |
# | 277       | -2.122e+0 | -0.2631   | 0.005465  | 2.29      | 2.125     |
# | 278       | -36.16    | -0.05777  | -0.09248  | 0.9066    | 0.951     |
# | 279       | -1.433e+0 | 0.1048    | -0.5403   | 1.939     | 1.307     |
# | 280       | -1.954e+0 | 0.1211    | 0.03413   | 1.485     | 1.543     |
# | 281       | -945.7    | -0.01819  | -0.1594   | 1.165     | 1.512     |
# | 282       | -3.584e+0 | 0.2468    | 0.4102    | 1.148     | 0.8983    |
# | 283       | -7.45e+03 | -0.1206   | 0.04713   | 2.435     | 1.138     |
# | 284       | -183.5    | 0.01868   | 0.1785    | 1.237     | 1.05      |
# | 285       | -145.7    | 0.07885   | 0.0438    | 0.8957    | 1.251     |
# | 286       | -1.063e+0 | -0.285    | -0.07184  | 0.9172    | 0.8207    |
# | 287       | -69.81    | 0.08889   | 0.002168  | 1.254     | 1.111     |
# | 288       | -1.104e+0 | -0.1098   | -0.2271   | 0.7902    | 1.254     |
# | 289       | -9.711e+0 | 1.044     | 0.3296    | 1.368     | 3.0       |
# | 290       | -160.4    | -0.0464   | -0.1295   | 1.302     | 0.9881    |
# | 291       | -231.2    | 0.1208    | 0.08551   | 0.8744    | 1.233     |
# | 292       | -458.6    | 0.1179    | 0.1901    | 1.102     | 0.7552    |
# | 293       | -918.4    | -0.1016   | 0.2299    | 1.383     | 0.8967    |
# | 294       | -59.99    | 0.1831    | -0.03898  | 0.9725    | 0.9715    |
# | 295       | -152.4    | 0.008939  | -0.1149   | 0.932     | 0.7795    |
# | 296       | -1.824e+0 | -0.09788  | 0.19      | 1.697     | 1.08      |
# | 297       | -1.034e+0 | 0.3331    | -0.3581   | 1.444     | 1.881     |
# | 298       | -135.1    | 0.1526    | 0.0003424 | 1.268     | 0.8703    |
# | 299       | -42.54    | 0.02708   | 0.124     | 0.9154    | 1.041     |
# | 300       | -113.4    | -0.1013   | 0.07652   | 1.224     | 1.095     |
# | 301       | -58.85    | -0.02914  | -0.02191  | 0.8426    | 0.881     |
# | 302       | -1.786e+0 | -0.07272  | -0.02092  | 1.795     | 0.8197    |
# | 303       | -22.11    | 0.09079   | -0.04601  | 1.018     | 0.8414    |
# | 304       | -2.867e+0 | -0.1763   | 2.131     | 2.887     | 2.992     |
# | 305       | -47.06    | -0.04077  | 0.1387    | 0.989     | 0.9208    |
# | 306       | -824.3    | -0.2091   | 0.116     | 0.7877    | 0.9473    |
# | 307       | -1.946e+0 | -0.002032 | -0.3736   | 1.186     | 0.9095    |
# | 308       | -221.9    | -0.2142   | -0.04654  | 1.134     | 0.9664    |
# | 309       | -185.9    | -0.197    | 0.02447   | 1.021     | 0.8916    |
# | 310       | -533.0    | 0.0844    | 0.07196   | 0.8214    | 1.353     |
# | 311       | -3.716e+0 | -0.3378   | 0.07613   | 1.003     | 1.58      |
# | 312       | -610.5    | -0.1767   | 0.133     | 1.204     | 0.7707    |
# | 313       | -295.2    | -0.01594  | -0.1455   | 1.014     | 0.7446    |
# | 314       | -6.551e+0 | 0.1052    | 0.0527    | 0.8919    | 2.247     |
# | 315       | -362.9    | 0.1145    | 0.2174    | 0.9179    | 1.142     |
# | 316       | -499.2    | -0.08679  | -0.06632  | 1.191     | 1.396     |
# | 317       | -319.1    | 0.02083   | -0.1837   | 0.8013    | 1.054     |
# | 318       | -7.769e+0 | 0.2848    | 0.04543   | 0.7369    | 1.978     |
# | 319       | -296.9    | 0.1008    | -0.1296   | 1.263     | 0.7999    |
# | 320       | -3.235e+0 | 0.1326    | -0.07624  | 2.019     | 0.942     |
# | 321       | -1.206e+0 | 0.2454    | 0.2378    | 0.9769    | 0.813     |
# | 322       | -242.2    | -0.04754  | -0.003026 | 1.415     | 1.092     |
# | 323       | -28.72    | -0.0504   | -0.001341 | 0.8852    | 1.072     |
# | 324       | -2.085e+0 | -0.2579   | -0.04238  | 1.323     | 2.937     |
# | 325       | -33.27    | 0.03779   | 0.004054  | 1.26      | 0.9005    |
# | 326       | -39.03    | -0.06298  | 0.06372   | 1.117     | 1.14      |
# | 327       | -504.6    | -0.06726  | 0.2072    | 0.9823    | 1.293     |
# | 328       | -521.2    | 0.03735   | 0.1835    | 0.7455    | 0.9334    |
# | 329       | -310.9    | 0.2279    | -0.03739  | 1.079     | 1.207     |
# | 330       | -173.0    | -0.06391  | -0.1468   | 1.269     | 1.01      |
# | 331       | -815.8    | 0.1666    | 0.159     | 1.239     | 1.367     |
# | 332       | -134.3    | -0.0233   | 0.1697    | 0.8782    | 1.037     |
# | 333       | -232.2    | 0.1535    | 0.07257   | 0.8482    | 1.167     |
# | 334       | -2.159e+0 | -0.2008   | -0.1077   | 1.454     | 0.666     |
# | 335       | -1.077e+0 | 0.1539    | -0.2561   | 1.209     | 0.7931    |
# | 336       | -309.4    | -0.2377   | 0.03959   | 1.024     | 0.9627    |
# | 337       | -764.2    | -0.1721   | -0.1429   | 0.7969    | 1.139     |
# | 338       | -639.9    | 0.06349   | -0.09871  | 0.6887    | 1.047     |
# | 339       | -781.5    | 0.1425    | -0.05429  | 1.468     | 0.7762    |
# | 340       | -915.7    | 0.28      | 0.201     | 1.19      | 0.8763    |
# | 341       | -4.134e+0 | 0.4737    | 0.04744   | 1.229     | 1.373     |
# | 342       | -1.077e+0 | 0.3486    | -0.0302   | 1.269     | 0.8524    |
# | 343       | -446.2    | 0.03017   | 0.0005773 | 1.088     | 1.465     |
# | 344       | -26.6     | -0.1194   | -0.01688  | 1.077     | 1.015     |
# | 345       | -34.07    | -0.02071  | -0.02631  | 1.162     | 0.8316    |
# | 346       | -286.2    | -0.04981  | 0.1872    | 1.201     | 0.8464    |
# | 347       | -1.494e+0 | 0.1298    | -0.3529   | 1.012     | 0.958     |
# | 348       | -605.9    | 0.1463    | -0.007919 | 0.699     | 1.066     |
# | 349       | -74.07    | 0.143     | -0.001056 | 0.9026    | 1.106     |
# | 350       | -239.4    | -0.1935   | -0.04959  | 0.9003    | 1.007     |
# | 351       | -493.0    | 0.2777    | 0.04531   | 0.9069    | 1.094     |
# | 352       | -76.82    | 0.1327    | 0.02689   | 1.258     | 0.9359    |
# | 353       | -247.8    | 0.2036    | 0.007749  | 1.159     | 1.222     |
# | 354       | -1.016e+0 | -0.02936  | -0.1022   | 1.615     | 0.8547    |
# | 355       | -573.6    | 0.2979    | -0.007921 | 1.284     | 0.9598    |
# | 356       | -21.57    | -0.007661 | 0.0966    | 0.9381    | 0.9196    |
# | 357       | -1.846e+0 | 0.208     | 0.2159    | 0.6961    | 1.118     |
# | 358       | -422.9    | 0.04033   | -0.1519   | 0.7381    | 0.9592    |
# | 359       | -278.3    | 0.1751    | 0.06791   | 1.307     | 1.145     |
# | 360       | -266.0    | 0.1813    | -0.01969  | 0.812     | 1.068     |
# | 361       | -2.39e+03 | 0.03536   | 0.3044    | 1.03      | 1.647     |
# | 362       | -347.1    | 0.237     | -0.1319   | 1.147     | 1.079     |
# | 363       | -89.63    | -0.1145   | 0.01098   | 1.213     | 1.091     |
# | 364       | -693.9    | 0.2054    | 0.1846    | 0.8121    | 0.9944    |
# | 365       | -121.4    | 0.01154   | 0.1794    | 1.028     | 0.863     |
# | 366       | -120.3    | -0.06042  | 0.1569    | 1.192     | 0.9983    |
# | 367       | -1.859e+0 | 0.05405   | 0.02975   | 1.198     | 1.734     |
# | 368       | -1.703e+0 | -0.232    | -0.1644   | 0.884     | 1.402     |
# | 369       | -388.4    | 0.1166    | -0.2026   | 1.265     | 1.055     |
# | 370       | -24.83    | 0.04248   | -0.06671  | 0.8712    | 0.9749    |
# | 371       | -28.05    | -0.005593 | -0.126    | 1.01      | 1.063     |
# | 372       | -367.3    | 0.1625    | -0.002689 | 0.9848    | 0.7032    |
# | 373       | -10.36    | 0.00611   | 0.03046   | 1.156     | 0.8829    |
# | 374       | -282.2    | -0.1285   | -0.0901   | 1.248     | 1.184     |
# | 375       | -241.8    | -0.05048  | -0.182    | 0.8668    | 1.041     |
# | 376       | -257.5    | -0.03204  | 0.09462   | 0.7952    | 0.8104    |
# | 377       | -75.17    | 0.1321    | 0.09887   | 0.9903    | 0.8482    |
# | 378       | -231.8    | -0.05366  | -0.2155   | 1.143     | 1.057     |
# | 379       | -1.355e+0 | 0.1209    | -0.09296  | 1.733     | 1.035     |
# | 380       | -1.962e+0 | -0.3074   | 0.141     | 1.505     | 0.9795    |
# | 381       | -6.845    | -0.02834  | -0.02539  | 1.125     | 1.07      |
# | 382       | -365.2    | 0.02545   | 0.2495    | 1.068     | 0.8842    |
# | 383       | -456.7    | 0.03064   | 0.001427  | 1.323     | 1.367     |
# | 384       | -191.4    | 0.05466   | 0.02901   | 0.7925    | 1.155     |
# | 385       | -1.284e+0 | 0.1768    | -0.09645  | 0.7042    | 1.248     |
# | 386       | -10.3     | 0.08998   | 0.04516   | 1.148     | 0.952     |
# | 387       | -709.4    | 0.1501    | -0.174    | 0.8346    | 0.7766    |
# | 388       | -1.409e+0 | 0.2532    | -0.2524   | 0.8612    | 1.03      |
# | 389       | -347.3    | 0.01741   | 0.1339    | 1.07      | 1.383     |
# | 390       | -946.4    | 0.1175    | -0.1859   | 1.428     | 0.8076    |
# | 391       | -380.1    | -0.1974   | 0.07437   | 1.331     | 0.9597    |
# | 392       | -523.7    | -0.123    | -0.2056   | 1.284     | 1.098     |
# | 393       | -583.7    | -0.1761   | -0.08326  | 1.34      | 0.812     |
# | 394       | -2.493e+0 | 0.3206    | 0.04746   | 2.983     | 1.744     |
# | 395       | -358.3    | 0.1644    | 0.02745   | 0.9342    | 1.339     |
# | 396       | -531.9    | 0.01824   | -0.01931  | 1.393     | 1.317     |
# | 397       | -1.4e+03  | 0.04535   | -0.01134  | 1.788     | 0.9503    |
# | 398       | -72.47    | 0.1296    | -0.05304  | 1.259     | 1.006     |
# | 399       | -525.5    | -0.2525   | -0.08796  | 1.198     | 0.9753    |
# | 400       | -799.9    | -0.155    | -0.06262  | 1.417     | 0.7775    |
# | 401       | -166.7    | -0.1466   | -0.1239   | 1.142     | 0.9649    |
# | 402       | -438.7    | -0.07532  | 0.01748   | 1.032     | 1.434     |
# | 403       | -196.7    | -0.1617   | -0.1273   | 1.016     | 0.9207    |
# | 404       | -43.82    | 0.1095    | 0.06146   | 0.9482    | 1.122     |
# | 405       | -106.3    | 0.1087    | -0.07773  | 0.8756    | 0.8397    |
# =========================================================================
# Final Result:  {'target': -2.298821149528547, 'params': {'m1_': -0.054260095917593176, 'm2_': 0.01313927225250211, 'v1_': 0.9756854629741132, 'v2_': 0.989144696502956}}

# %%
run_targets = [np.minimum.accumulate(-i[1].space.target) for i in optimization_results]

# %%
plt.plot(run_targets[0])
plt.scatter(np.arange(len(run_targets[0])), run_targets[0], s=6)
plt.plot(run_targets[1])
plt.scatter(np.arange(len(run_targets[1])), run_targets[1], s=6)
plt.plot(run_targets[2])
plt.scatter(np.arange(len(run_targets[2])), run_targets[2], s=6)
plt.plot(run_targets[3])
plt.scatter(np.arange(len(run_targets[3])), run_targets[3], s=6)
plt.plot(run_targets[4])
plt.scatter(np.arange(len(run_targets[4])), run_targets[4], s=6)
plt.show()

# %%
best_params = optimization_results[np.argmax([x[0]['target'] for x in optimization_results])][0]

# %%
best_params
# Out:
# {'target': -0.0007374662823684951,
#  'params': {'m1_': 0.025408062820662103,
#   'm2_': -0.025796181416214203,
#   'v1_': 1.0516477496795344,
#   'v2_': 0.9973254711569299}}

# %%
ratios = synthesis_model(train_data=sample,
                         number_synthetic_datasets=M,
                         m1_=best_params['params']['m1_'],
                         m2_=best_params['params']['m2_'],
                         v1_=best_params['params']['v1_'],
                         v2_=best_params['params']['v2_'])

# %%
np.mean(ratios)
# Out:
# 0.9935200364105423

# %%
10*0.016
# Out:
# 0.16

# %% [markdown]
# ***
